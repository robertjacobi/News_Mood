# %%
# Import Dependencies
# %matplotlib inline
import pandas as pd
import tweepy
import json
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import and Initialize Sentiment Analyzer

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account
target_user = "BBCWorld"

# Counter
counter = 1

# Variables for holding sentiments
bbc_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
bbc_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in bbc_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    bbc_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
bbc_sentiments_df = pd.DataFrame.from_dict(bbc_sentiments)
bbc_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.6908  Mon Aug 27 16:19:07 +0000 2018     0.370    0.630     0.000
# 1    0.4404  Mon Aug 27 16:07:47 +0000 2018     0.000    0.818     0.182
# 2   -0.2960  Mon Aug 27 15:58:09 +0000 2018     0.136    0.864     0.000
# 3   -0.2960  Mon Aug 27 15:50:03 +0000 2018     0.180    0.820     0.000
# 4    0.0258  Mon Aug 27 15:42:18 +0000 2018     0.000    0.845     0.155
#
#      Source                                               Text  Tweets Ago
# 0  BBCWorld  Saad Lamjarred: Moroccan singer faces third ra...           1
# 1  BBCWorld  Just when you thought it was safe to go back i...           2
# 2  BBCWorld  Jos Brech was identified as a suspect after th...           3
# 3  BBCWorld  John McCain: White House urged to lower flags ...           4
# 4  BBCWorld  RT @BBCBusiness: US-Mexico reach NAFTA breakth...           5

# %%
# Target Account
target_user = "CBSNews"

# Counter
counter = 1

# Variables for holding sentiments
cbs_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cbs_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
cbs_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
cbs_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.8442  Mon Aug 27 16:14:41 +0000 2018     0.503    0.497     0.000
# 1    0.0000  Mon Aug 27 16:01:11 +0000 2018     0.000    1.000     0.000
# 2    0.0000  Mon Aug 27 16:01:08 +0000 2018     0.000    1.000     0.000
# 3    0.7906  Mon Aug 27 16:00:01 +0000 2018     0.000    0.667     0.333
# 4    0.0000  Mon Aug 27 15:55:56 +0000 2018     0.000    1.000     0.000
#
#     Source                                               Text  Tweets Ago
# 0  CBSNews  Philippine priest says "death squad" has force...           1
# 1  CBSNews  Reporter: Mr. President, any thoughts on John ...           2
# 2  CBSNews  Reporter: Mr. President, any thoughts on John ...           3
# 3  CBSNews  Honoring John McCain: The week of events celeb...           4
# 4  CBSNews  "I really hope... that the part [of the trade ...           5

# %%
# Target Account
target_user = "CNN"

# Counter
counter = 1

# Variables for holding sentiments
cnn_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cnn_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cnn_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cnn_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
cnn_sentiments_df = pd.DataFrame.from_dict(cnn_sentiments)
cnn_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Mon Aug 27 16:20:07 +0000 2018     0.000    1.000     0.000
# 1   -0.6705  Mon Aug 27 16:10:07 +0000 2018     0.258    0.645     0.097
# 2   -0.2500  Mon Aug 27 16:00:08 +0000 2018     0.315    0.494     0.191
# 3   -0.4588  Mon Aug 27 15:50:03 +0000 2018     0.167    0.833     0.000
# 4   -0.5719  Mon Aug 27 15:40:06 +0000 2018     0.252    0.748     0.000
#
#   Source                                               Text  Tweets Ago
# 0    CNN  The White House flag returned to its regular p...           1
# 1    CNN  Four teens, who were attending a slumber party...           2
# 2    CNN  Gaming community and friends mourn the Jackson...           3
# 3    CNN  Facebook has banned 20 organizations and indiv...           4
# 4    CNN  Don't try to sugarcoat the horror of Jacksonvi...           5

# %%
# Target Account
target_user = "FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
fox_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
fox_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in fox_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    fox_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
fox_sentiments_df = pd.DataFrame.from_dict(fox_sentiments)
fox_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4939  Mon Aug 27 16:09:57 +0000 2018       0.0    0.802     0.198
# 1    0.0000  Mon Aug 27 16:01:33 +0000 2018       0.0    1.000     0.000
# 2    0.5574  Mon Aug 27 16:00:36 +0000 2018       0.0    0.796     0.204
# 3    0.5228  Mon Aug 27 16:00:02 +0000 2018       0.0    0.849     0.151
# 4    0.6478  Mon Aug 27 15:57:42 +0000 2018       0.0    0.763     0.237
#
#     Source                                               Text  Tweets Ago
# 0  FoxNews  JUST IN: Trump says he's 'terminating' NAFTA, ...           1
# 1  FoxNews  .@POTUS: “This is one of the largest trade dea...           2
# 2  FoxNews  .@POTUS: “One of the things that I’m excited a...           3
# 3  FoxNews  .@POTUS: “Our economy is up, it’s never been t...           4
# 4  FoxNews  .@POTUS: “It’s an incredible deal. It’s an inc...           5

# %%
# Target Account
target_user = "nytimes"

# Counter
counter = 1

# Variables for holding sentiments
nyt_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
nyt_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in nyt_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    nyt_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
nyt_sentiments_df = pd.DataFrame.from_dict(nyt_sentiments)
nyt_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.5267  Mon Aug 27 16:15:06 +0000 2018     0.000    0.841     0.159
# 1   -0.7650  Mon Aug 27 16:00:04 +0000 2018     0.258    0.742     0.000
# 2    0.2960  Mon Aug 27 15:45:08 +0000 2018     0.083    0.785     0.132
# 3    0.0000  Mon Aug 27 15:29:05 +0000 2018     0.000    1.000     0.000
# 4    0.5859  Mon Aug 27 15:15:06 +0000 2018     0.000    0.833     0.167
#
#     Source                                               Text  Tweets Ago
# 0  nytimes  Underrepresented students are less likely to t...           1
# 1  nytimes  A doctor in Hong Kong has been accused of kill...           2
# 2  nytimes  The White House inexplicably flew the American...           3
# 3  nytimes  In Opinion\n\nAuthor Matt Welch writes, "If we...           4
# 4  nytimes  The 96-year-old French painter and author Fran...           5

# %%
# Concatenate each individual news outlet dataframe into a master dataframe

news_tweets_df = pd.concat([bbc_sentiments_df, cbs_sentiments_df, cnn_sentiments_df, fox_sentiments_df, nyt_sentiments_df], ignore_index=True)

# Organize column order
news_tweets_df = news_tweets_df[["Source", "Date", "Text", "Positive", "Neutral", "Negative", "Compound", "Tweets Ago"]]

# Output the df to a csv file
news_tweets_df.to_csv("Output/news_tweets.csv", encoding='utf-8', index=False)

# %%
# Use loc to grab plot data points for each news outlet

bbc_com = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"]
bbc_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Tweets Ago"]

cbs_com = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"]
cbs_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Tweets Ago"]

cnn_com = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"]
cnn_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Tweets Ago"]

fox_com = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"]
fox_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Tweets Ago"]

nyt_com = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"]
nyt_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Tweets Ago"]

#Setting Subplot for visual
fig, ax=plt.subplots()

# Plot the points gathered above
ax.scatter(bbc_tweets, bbc_com, s=75, marker ="o", color="lightskyblue", alpha=0.75, edgecolors="black")
ax.scatter(cbs_tweets, cbs_com, s=75, marker ="o", color="green", alpha=0.75, edgecolors="black")
ax.scatter(cnn_tweets, cnn_com, s=75, marker ="o", color="red", alpha=0.75, edgecolors="black")
ax.scatter(fox_tweets, fox_com, s=75, marker ="o", color="blue", alpha=0.75, edgecolors="black")
ax.scatter(nyt_tweets, nyt_com, s=75, marker ="o", color="yellow", alpha=0.75, edgecolors="black")

ax.set_xlim(100,0)
ax.set_ylim(-1, 1)
ax.set_facecolor("lavender")


# Set the grid lines behind the plots, remove unneccessary spines, and set tickmarks
ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([-1.0, -0.50, 0.0, 0.50, 1.00])
plt.tick_params(bottom=False, left=False)

ax.grid(color="white")

# Label the scatterplot
plt.title("Sentiment Analysis of Media Tweets (8/27/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Incorporate a text label regarding circle size

bbc = plt.scatter([],[], s=75, marker = "o", color = "lightskyblue", edgecolors="black")
cbs = plt.scatter([],[], s=75, marker = "o", color = "green", edgecolors="black")
cnn = plt.scatter([],[], s=75, marker = "o", color = "red", edgecolors="black")
fox = plt.scatter([],[], s=75, marker = "o", color = "blue", edgecolors="black")
ny_times = plt.scatter([],[], s=75, marker = "o", color = "gold", edgecolors="black")

# Create a legend
plt.legend((bbc, cbs, cnn, fox, ny_times), ("BBC", "CBS", "CNN", "Fox", "NY Times"), frameon=False, title="Media Sources", bbox_to_anchor=(1.01, 1))

#Set this so output file does not cut off legend
fig.tight_layout()

# Export graph for presentation
plt.savefig("Output/Sentiment_Analysis_Tweets.png")

plt.show()

# %%
#Setting Subplot for visual
fig, ax=plt.subplots()

#Collect chart values using loc for each news outlet
bbc_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"].mean()
cbs_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"].mean()
cnn_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"].mean()
fox_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"].mean()
nyt_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"].mean()

# data looks better without clutter

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tick_params(bottom=False, left=False) 

ax.set_facecolor("lavender")

#Create bar chart from values gathered above
plt.bar("BBC", bbc_com_mean, color ="lightskyblue", edgecolor="grey", align="center")
plt.bar("CBS", cbs_com_mean, color ="green", edgecolor="grey", align="center")
plt.bar("CNN", cnn_com_mean, color ="red", edgecolor="grey", align="center")
plt.bar("Fox", fox_com_mean, color ="blue", edgecolor="grey", align="center")
plt.bar("NYT", nyt_com_mean, color ="gold", edgecolor="grey", align="center")

plt.title("Overall Media Sentiment Based on Twitter (8/27/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    va = 'bottom'

    # If value of bar is negative: Place label below bar
    if y_value < 0:
        # Invert space to place label below
        space *= -1
        # Vertically align label at top
        va = 'top'

    # Use Y value as label and format number with one decimal place
    label = "{:.2f}".format(y_value)

    # Create annotation
    plt.annotate(
        label,
        (x_value, y_value),
        xytext=(0, space),
        textcoords="offset points",
        ha='center',
        va=va)
    
#Set this so output file does not cut off legend
fig.tight_layout()

# Export graph for presentation
plt.savefig("Output/Overall_Media_Sentiment.png")

plt.show()
