# %%
# Import Dependencies
# %matplotlib inline
import pandas as pd
import tweepy
import json
import matplotlib.pyplot as plt
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Import and Initialize Sentiment Analyzer

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Setup Tweepy API Authentication

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Account
target_user = "BBCWorld"

# Counter
counter = 1

# Variables for holding sentiments
bbc_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
bbc_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in bbc_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    bbc_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
bbc_sentiments_df = pd.DataFrame.from_dict(bbc_sentiments)
bbc_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.4019  Fri Aug 24 02:44:51 +0000 2018       0.0    0.722     0.278
# 1    0.0000  Fri Aug 24 00:57:39 +0000 2018       0.0    1.000     0.000
# 2    0.4047  Fri Aug 24 00:54:49 +0000 2018       0.0    0.729     0.271
# 3    0.0000  Fri Aug 24 00:32:06 +0000 2018       0.0    1.000     0.000
# 4    0.5574  Fri Aug 24 00:29:26 +0000 2018       0.0    0.660     0.340
#
#      Source                                               Text  Tweets Ago
# 0  BBCWorld  Turnbull's party ousts him as Australia PM htt...           1
# 1  BBCWorld  Malcolm Turnbull: Australia PM's leadership on...           2
# 2  BBCWorld  Papal visit: What sort of welcome awaits Pope ...           3
# 3  BBCWorld  Africa's week in pictures: 17-23 August 2018 h...           4
# 4  BBCWorld  The heroic Indian teens who conquered Everest ...           5

# %%
# Target Account
target_user = "CBSNews"

# Counter
counter = 1

# Variables for holding sentiments
cbs_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cbs_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cbs_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cbs_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
cbs_sentiments_df = pd.DataFrame.from_dict(cbs_sentiments)
cbs_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Fri Aug 24 03:03:02 +0000 2018     0.000    1.000     0.000
# 1    0.1779  Fri Aug 24 02:50:06 +0000 2018     0.146    0.662     0.192
# 2   -0.7189  Fri Aug 24 02:16:12 +0000 2018     0.214    0.786     0.000
# 3    0.0000  Fri Aug 24 01:55:35 +0000 2018     0.000    1.000     0.000
# 4    0.0000  Fri Aug 24 01:34:55 +0000 2018     0.000    1.000     0.000
#
#     Source                                               Text  Tweets Ago
# 0  CBSNews  Would stocks "crash" if Trump were impeached? ...           1
# 1  CBSNews  There's "no safe level of alcohol," major new ...           2
# 2  CBSNews  One woman says she was fired from her job at a...           3
# 3  CBSNews  DNC chair Tom Perez says proposed rule change ...           4
# 4  CBSNews  "MOM-SHAMED": An Illinois mom says cops were c...           5

# %%
# Target Account
target_user = "CNN"

# Counter
counter = 1

# Variables for holding sentiments
cnn_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
cnn_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in cnn_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    cnn_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
cnn_sentiments_df = pd.DataFrame.from_dict(cnn_sentiments)
cnn_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.0000  Fri Aug 24 03:01:02 +0000 2018     0.000    1.000     0.000
# 1   -0.6486  Fri Aug 24 02:51:04 +0000 2018     0.290    0.710     0.000
# 2   -0.4767  Fri Aug 24 02:46:04 +0000 2018     0.140    0.860     0.000
# 3    0.2500  Fri Aug 24 02:43:51 +0000 2018     0.000    0.909     0.091
# 4   -0.3182  Fri Aug 24 02:41:16 +0000 2018     0.108    0.892     0.000
#
#   Source                                               Text  Tweets Ago
# 0    CNN  California lawmakers vote to wipe out old pot ...           1
# 1    CNN  Trump says impeachment would crash the stock m...           2
# 2    CNN  Siraj Wahhaj, one of five people arrested afte...           3
# 3    CNN  RT @CNNTonight: National Enquirer publisher Da...           4
# 4    CNN  "One by one, the naval aviators and journalist...           5

# %%
# Target Account
target_user = "FoxNews"

# Counter
counter = 1

# Variables for holding sentiments
fox_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
fox_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in fox_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    fox_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
fox_sentiments_df = pd.DataFrame.from_dict(fox_sentiments)
fox_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0   -0.2942  Fri Aug 24 03:00:11 +0000 2018     0.144    0.856     0.000
# 1   -0.8225  Fri Aug 24 02:54:43 +0000 2018     0.632    0.368     0.000
# 2   -0.3400  Fri Aug 24 02:39:00 +0000 2018     0.179    0.821     0.000
# 3   -0.2960  Fri Aug 24 02:32:00 +0000 2018     0.282    0.513     0.205
# 4    0.5423  Fri Aug 24 02:25:00 +0000 2018     0.000    0.571     0.429
#
#     Source                                               Text  Tweets Ago
# 0  FoxNews  Utah mom confronts man peeping under 12-year-o...           1
# 1  FoxNews  Golden State Killer suspect faces consolidated...           2
# 2  FoxNews  DiGenova: Sessions 'Doesn't Understand His Job...           3
# 3  FoxNews  Second man convicted in killing of Chicago hon...           4
# 4  FoxNews  Cop adopts dog rescued from California wildfir...           5

# %%
# Target Account
target_user = "nytimes"

# Counter
counter = 1

# Variables for holding sentiments
nyt_sentiments = []

# Variable for max_id
oldest_tweet = None

# Get all tweets from home feed
nyt_public_tweets = api.user_timeline(target_user, count=100, max_id = oldest_tweet)

    # Loop through all tweets 
for tweet in nyt_public_tweets:

    # Print Tweets
    # print("Tweet {counter}: {tweet["text"]})
        
    # Run Vader Analysis on each tweet
    results = analyzer.polarity_scores(tweet["text"])
    compound = results["compound"]
    pos = results["pos"]
    neu = results["neu"]
    neg = results["neg"]
        
    # Get Tweet ID, subtract 1, and assign to oldest_tweet
    oldest_tweet = tweet['id'] - 1
        
    # Add sentiments for each tweet into a list
    nyt_sentiments.append({"Date": tweet["created_at"],
                           "Source": target_user,
                           "Text": tweet["text"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neg,
                           "Neutral": neu,
                           "Tweets Ago": counter})
        
    # Add to counter 
    counter += 1

# Convert sentiments to DataFrame
nyt_sentiments_df = pd.DataFrame.from_dict(nyt_sentiments)
nyt_sentiments_df.head()
# Out:
#    Compound                            Date  Negative  Neutral  Positive  \
# 0    0.1280  Fri Aug 24 03:03:52 +0000 2018     0.000    0.909     0.091
# 1   -0.0258  Fri Aug 24 03:02:04 +0000 2018     0.058    0.942     0.000
# 2   -0.3612  Fri Aug 24 02:47:03 +0000 2018     0.122    0.878     0.000
# 3   -0.7717  Fri Aug 24 02:30:08 +0000 2018     0.309    0.691     0.000
# 4   -0.2960  Fri Aug 24 02:17:03 +0000 2018     0.109    0.891     0.000
#
#     Source                                               Text  Tweets Ago
# 0  nytimes  Breaking News: Australia’s prime minister, Mal...           1
# 1  nytimes  3 men who took part in a white nationalist ral...           2
# 2  nytimes  RT @nytpolitics: President Trump’s tweet about...           3
# 3  nytimes  Steve Jobs' daughter, Lisa Brennan-Jobs, has w...           4
# 4  nytimes  RT @NYTHealth: Russian trolls accused of meddl...           5

# %%
news_tweets_df = pd.concat([bbc_sentiments_df, cbs_sentiments_df, cnn_sentiments_df, fox_sentiments_df, nyt_sentiments_df], ignore_index=True)

# %%
bbc_com = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"]
bbc_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Tweets Ago"]

cbs_com = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"]
cbs_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Tweets Ago"]

cnn_com = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"]
cnn_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Tweets Ago"]

fox_com = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"]
fox_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Tweets Ago"]

nyt_com = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"]
nyt_tweets = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Tweets Ago"]

# Introduce a subplot to utilize "ax" functions to modify the scatterplot grid and colors
fig, ax=plt.subplots()

ax.scatter(bbc_tweets, bbc_com, s=75, marker ="o", color="lightskyblue", alpha=0.75, edgecolors="black")
ax.scatter(cbs_tweets, cbs_com, s=75, marker ="o", color="green", alpha=0.75, edgecolors="black")
ax.scatter(cnn_tweets, cnn_com, s=75, marker ="o", color="red", alpha=0.75, edgecolors="black")
ax.scatter(fox_tweets, fox_com, s=75, marker ="o", color="blue", alpha=0.75, edgecolors="black")
ax.scatter(nyt_tweets, nyt_com, s=75, marker ="o", color="yellow", alpha=0.75, edgecolors="black")

ax.set_xlim(100,0)
ax.set_ylim(-1, 1)
ax.set_facecolor("lavender")


# Set the grid lines behind the plots and remove unneccessary spines
ax.set_axisbelow(True)
ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.set_yticks([-1.0, -0.50, 0.0, 0.50, 1.00])
plt.tick_params(bottom=False, left=False)

ax.grid(color="white")

plt.title("Sentiment Analysis of Media Tweets (8/22/18)")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")

# Create a legend
# Incorporate a text label regarding circle size

bbc = plt.scatter([],[], s=75, marker = "o", color = "lightskyblue", edgecolors="black")
cbs = plt.scatter([],[], s=75, marker = "o", color = "green", edgecolors="black")
cnn = plt.scatter([],[], s=75, marker = "o", color = "red", edgecolors="black")
fox = plt.scatter([],[], s=75, marker = "o", color = "blue", edgecolors="black")
ny_times = plt.scatter([],[], s=75, marker = "o", color = "gold", edgecolors="black")

plt.legend((bbc, cbs, cnn, fox, ny_times), ("BBC", "CBS", "CNN", "Fox", "NY Times"), frameon=False, title="Media Sources", bbox_to_anchor=(1.01, 1))

plt.show()

# %%
#Setting Subplot for visual
fig, ax=plt.subplots()

bbc_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "BBCWorld"]["Compound"].mean()
cbs_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CBSNews"]["Compound"].mean()
cnn_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "CNN"]["Compound"].mean()
fox_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "FoxNews"]["Compound"].mean()
nyt_com_mean = news_tweets_df.loc[news_tweets_df["Source"] == "nytimes"]["Compound"].mean()

ax.spines['top'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.set_facecolor("lavender")

plt.tick_params(bottom=False, left=False)                            


plt.bar("BBC", bbc_com_mean, color ="lightskyblue", edgecolor="grey", align="center")
plt.bar("CBS", cbs_com_mean, color ="green", edgecolor="grey", align="center")
plt.bar("CNN", cnn_com_mean, color ="red", edgecolor="grey", align="center")
plt.bar("Fox", fox_com_mean, color ="blue", edgecolor="grey", align="center")
plt.bar("NYT", nyt_com_mean, color ="gold", edgecolor="grey", align="center")

plt.show()
